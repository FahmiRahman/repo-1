# %%
number_1 = input("Enter the first number: ")
number_2 = input("Enter the second number: ")

print("number 1:",number_1)
print("number 2:",number_2)

# %%
def number_type(number):
    try:
        num = float(number)
        if num.is_integer():
            return "Integer"
        else:
            return "Decimal"
    except ValueError:
        return "Invalid input"
    
number_1 = input("Enter the first number: ")
number_2 = input("Enter the second number: ")

num_1_type = number_type(number_1)
num_2_type = number_type(number_2)

print(f"The first number is: {num_1_type}")
print(f"The second number is: {num_2_type}")

# %%
def calculate(num_1, num_2, operation):
    print(f"Calculating: {num_1} {operation} {num_2}")

    if operation == '+':
        result = num_1 + num_2
    elif operation == '-':
        result = num_1 - num_2
    elif operation == '*':
        result = num_1 * num_2
    elif operation == '/':
        if num_2 != 0:
            result = num_1 / num_2
        else:
            print("Error: Division by zero!")
            result = None
    elif operation == '**':
        result = num_1 ** num_2
        print(f"Exponentiation: {num_1} ** {num_2} = {result}")
    else:
        print("Error: Invalid operation!")
        result = None
    print(f"Operation Result: {result}")
    return result

def again():
    calc_again = input("Do you want to perform another calculation? (Y/N):")
    if calc_again.upper() == 'Y' or calc_again.upper() == 'YY':
        return True
    else:
        return False

 

while True:
    try:
        num_1 = float(input("Enter the first number: "))
        num_2 = float(input("Enter the second number: "))
        operation = input("Please type the operation that you would like to perfrom (+, -, *, /, or **): ")

        print(f"Inputs: num_1={num_1}, num_2={num_2}, operation={operation}")

        result = calculate(num_1, num_2, operation)
        print(f"Result after calculation: {result}")

        if result is not None:
            print(f"The result of {num_1} {operation} {num_2} = {result}")
        else:
            print("Calculation returned None, check your input or operation.")
    except ValueError:
        print("Invalid input! Please enter nurmeric values.")

        if not again():
            print("see you later.")
            break
